# %%
import pandas as pd
import os

# %%
base_dir = "/media/randell-crapy/0E9103460E910346/tradfi/data/optionsDX"

# %%
vixMarch = pd.read_csv(os.path.join(base_dir,"vix_eod_2023q1-krx1qq","vix_eod_202303.txt"))

# %%
vixMarch.head(10)
# Out:
#    [QUOTE_UNIXTIME]   [QUOTE_READTIME]  [QUOTE_DATE]   [QUOTE_TIME_HOURS]  \
# 0        1677704400   2023-03-01 16:00    2023-03-01                 16.0
# 1        1677704400   2023-03-01 16:00    2023-03-01                 16.0
# 2        1677704400   2023-03-01 16:00    2023-03-01                 16.0
# 3        1677704400   2023-03-01 16:00    2023-03-01                 16.0
# 4        1677704400   2023-03-01 16:00    2023-03-01                 16.0
# 5        1677704400   2023-03-01 16:00    2023-03-01                 16.0
# 6        1677704400   2023-03-01 16:00    2023-03-01                 16.0
# 7        1677704400   2023-03-01 16:00    2023-03-01                 16.0
# 8        1677704400   2023-03-01 16:00    2023-03-01                 16.0
# 9        1677704400   2023-03-01 16:00    2023-03-01                 16.0
#
#     [UNDERLYING_LAST]  [EXPIRE_DATE]   [EXPIRE_UNIX]   [DTE]   [C_DELTA]  \
# 0               20.67     2023-03-01      1677704400     0.0         1.0
# ...

# %%
def absoluteFilePaths(directory):
    for dirpath,_,filenames in os.walk(directory):
        for f in filenames:
            yield os.path.abspath(os.path.join(dirpath, f))
